# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
attractions = pd.read_csv("exports/clean_attractions.csv")
categories=pd.read_csv("exports/categories.csv")
hotels = pd.read_csv("exports/hotels1.csv")
pricing = pd.read_csv("exports/prices1.csv")
visitors= pd.read_csv("exports/visitor_stats.csv", parse_dates=['year'],
                     index_col='year',)

# %%
visitors
# Out:
#                           attraction_site  visitor_count
# year
# 2020-01-01      Lake Nakuru National Park          50000
# 2021-01-01      Lake Nakuru National Park          75000
# 2022-01-01      Lake Nakuru National Park         150000
# 2023-01-01      Lake Nakuru National Park         200000
# 2020-01-01                Menengai Crater          12000
# ...                                   ...            ...
# 2023-01-01  Oserengoni Wildlife Sanctuary           7000
# 2020-01-01                   Dodo's Tower           1000
# 2021-01-01                   Dodo's Tower           2000
# 2022-01-01                   Dodo's Tower           3000
# 2023-01-01                   Dodo's Tower           3500
#
# [80 rows x 2 columns]

# %%
ax = visitors.plot(
    kind='bar',
    style="ko--",
    title = "Visitor Statistics",
    xlabel= "year" ,
    ylabel = "visitor_count",
    #ylim =[50000, 250000],
    label="visitors",
    figsize=(12,6)
)
ax.legend()

# %%
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='68727359-a045-45a5-b0bb-cc73d65ec5e2'>
#   <div id="df0a2126-febc-4e51-8b65-0f881d203d43" data-root-id="68727359-a045-45a5-b0bb-cc73d65ec5e2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
ax = visitors.hvplot(
    #kind='bar',
    #style="ko--",
    #title = "Visitor Statistics",
    xlabel= "year" ,
    ylabel = "visitor_count",
    ylim =[50000, 250000],
    label="visitors",
    #figsize=(12,6)
)
#ax.legend()

# %%
visits2020= visitors.loc[(visitors.index =="2020")]

# %%
visitors.head()
# Out:
#                       attraction_site  visitor_count
# year
# 2020-01-01  Lake Nakuru National Park          50000
# 2021-01-01  Lake Nakuru National Park          75000
# 2022-01-01  Lake Nakuru National Park         150000
# 2023-01-01  Lake Nakuru National Park         200000
# 2020-01-01            Menengai Crater          12000

# %%
from shapely import Point

# %%
point = Point(2.2, 4.2)
point3D = Point(9.26, -2.456, 0.57)
point3D
# Out:
# <POINT Z (9.26 -2.456 0.57)>
